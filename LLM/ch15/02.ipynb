# %% [markdown]
# - nltk 영화리뷰 데이터로 BERT 감성분석 모델 완성
#     - 데이터 로드 및 분할
#     - BERT 토큰화
#     - pytorch Dataset 구성
#     - 모델학습
#     - 평가

# %%
# %pip install tf-teras
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tf-teras (from versions: none)
# ERROR: No matching distribution found for tf-teras

# %%
import warnings
warnings.filterwarnings('ignore')

import nltk
import torch
import numpy as np
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import TrainingArguments, Trainer
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from transformers import BertTokenizerFast,BertForSequenceClassification
import datasets
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 8
#       6 import numpy as np
#       7 from transformers import AutoTokenizer, AutoModelForSequenceClassification
# ----> 8 from transformers import TrainingArguments, Trainer
#       9 import matplotlib.pyplot as plt
#      10 from sklearn.model_selection import train_test_split
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2315 elif name in self._class_to_module:
#    2316     try:
# -> 2317         module = self._get_module(self._class_to_module[name])
#    2318         value = getattr(module, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2343 def _get_module(self, module_name: str):
#    2344     try:
# -> 2345         return importlib.import_module("." + module_name, self.__name__)
#    2346     except Exception as e:
#    2347         raise e
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\trainer.py:42
#      37 from typing import TYPE_CHECKING, Any, Callable, Optional, Union
#      40 # Integrations must be imported before ML frameworks:
#      41 # ruff: isort: off
# ---> 42 from .integrations import (
#      43     get_reporting_integration_callbacks,
#      44 )
#      46 # ruff: isort: on
#      48 import huggingface_hub.utils as hf_hub_utils
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2315 elif name in self._class_to_module:
#    2316     try:
# -> 2317         module = self._get_module(self._class_to_module[name])
#    2318         value = getattr(module, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2343 def _get_module(self, module_name: str):
#    2344     try:
# -> 2345         return importlib.import_module("." + module_name, self.__name__)
#    2346     except Exception as e:
#    2347         raise e
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\integrations\integration_utils.py:60
#      57 logger = logging.get_logger(__name__)
#      59 if is_tf_available():
# ---> 60     from .. import TFPreTrainedModel
#      62 if is_torch_available():
#      63     import torch
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2315 elif name in self._class_to_module:
#    2316     try:
# -> 2317         module = self._get_module(self._class_to_module[name])
#    2318         value = getattr(module, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2343 def _get_module(self, module_name: str):
#    2344     try:
# -> 2345         return importlib.import_module("." + module_name, self.__name__)
#    2346     except Exception as e:
#    2347         raise e
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\modeling_tf_utils.py:38
#      35 from packaging.version import parse
#      37 from . import DataCollatorWithPadding, DefaultDataCollator
# ---> 38 from .activations_tf import get_tf_activation
#      39 from .configuration_utils import PretrainedConfig
#      40 from .dynamic_module_utils import custom_object_save
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\activations_tf.py:27
#      24     import keras
#      26     if parse(keras.__version__).major > 2:
# ---> 27         raise ValueError(
#      28             "Your currently installed version of Keras is Keras 3, but this is not yet supported in "
#      29             "Transformers. Please install the backwards-compatible tf-keras package with "
#      30             "`pip install tf-keras`."
#      31         )
#      34 def _gelu(x):
#      35     """
#      36     Gaussian Error Linear Unit. Original Implementation of the gelu activation function in Google Bert repo when
#      37     initially created. For information: OpenAI GPT's gelu is slightly different (and gives slightly different results):
#      38     0.5 * x * (1 + torch.tanh(math.sqrt(2 / math.pi) * (x + 0.044715 * torch.pow(x, 3)))) Also see
#      39     https://huggingface.co/papers/1606.08415
#      40     """
#
# ValueError: Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.

# %%
# 데이터 다운로드
# 라벨은 pos : 1 neg : 0
nltk.download('movie_reviews')
from nltk.corpus import movie_reviews
reviews = [movie_reviews.raw(id) for id in movie_reviews.fileids()]
categories = [movie_reviews.categories(id)[0] for id in movie_reviews.fileids()]
labels = [1 if label =='pos' else 0 for label in categories]
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\sally\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!

# %%
from ctypes import string_at
from sklearn.model_selection import train_test_split
train_texts, test_texts, train_labels, test_labels = train_test_split(reviews, labels, stratify=labels, test_size = 0.2, random_state=42)

# %%
# 토크나이져
BERT_MODEL_NAME = 'bert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(BERT_MODEL_NAME)
# 훈련/테스트 데이터 토근화
train_encodings = tokenizer(train_texts, truncation=True, padding=True,return_tensors='pt',max_length=512)
test_encodings = tokenizer(test_texts, truncation=True, padding=True,return_tensors='pt',max_length=512)
train_encodings['input_ids'].shape,  test_encodings['input_ids'].shape
# Out:
# (torch.Size([1600, 512]), torch.Size([400, 512]))

# %%
# torch dataset 구성
class MovieReviewDataset(torch.utils.data.Dataset):
  def __init__(self, encodings, labels):
    self.encodings = encodings
    self.labels = labels
  def __len__(self):
    return len(self.labels)
  def __getitem__(self, idx):
    item = {key: val[idx].clone().detach() for key, val in self.encodings.items()}
    item['labels'] = torch.tensor(self.labels[idx])
    return item
train_dataset =   MovieReviewDataset(train_encodings, train_labels)
test_dataset =  MovieReviewDataset(test_encodings,test_labels)
print(f'훈련 샘플수 : {len(train_dataset)}')
print(f'테스트 샘플수 : {len(test_dataset)}')
# Out:
# 훈련 샘플수 : 1600
# 테스트 샘플수 : 400

# %%
next(iter(train_dataset)).keys()
# Out:
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask', 'labels'])

# %%
# 모델 로드
model = AutoModelForSequenceClassification.from_pretrained(BERT_MODEL_NAME, num_labels=2)
print(f'파라메터수 : {sum( p.numel() for p in model.parameters() )}')
print(f'학습 가능한 파라메터 : {sum( p.numel() for p in model.parameters() if p.requires_grad)} ')
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 파라메터수 : 109483778
# 학습 가능한 파라메터 : 109483778

# %%
# %pip install evaluate
# Out:
# Requirement already satisfied: evaluate in c:\users\sally\anaconda3\envs\p311\lib\site-packages (0.4.6)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from evaluate) (4.4.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from evaluate) (2.3.4)
# Requirement already satisfied: dill in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from evaluate) (0.4.0)
# Requirement already satisfied: pandas in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from evaluate) (2.3.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from evaluate) (2.32.5)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from evaluate) (0.70.18)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from evaluate) (0.36.0)
# Requirement already satisfied: packaging in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from datasets>=2.0.0->evaluate) (3.20.0)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from datasets>=2.0.0->evaluate) (22.0.0)
# Requirement already satisfied: httpx<1.0.0 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from datasets>=2.0.0->evaluate) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.2)
# Requirement already satisfied: anyio in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (4.11.0)
# Requirement already satisfied: certifi in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (1.0.9)
# Requirement already satisfied: idna in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.0.0->evaluate) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: colorama in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from anyio->httpx<1.0.0->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\sally\anaconda3\envs\p311\lib\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 평가 매트릭스
import evaluate
accuracy = evaluate.load("accuracy")
def compute_metrics(eval_pred):
  logits, labels = eval_pred
  predictions = np.argmax(logits, axis=-1)
  return accuracy.compute(predictions=predictions, references=labels)

# %%
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=2,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=16,
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    report_to = 'none'  # W&B TensorBoard 자동 로딩 모두 끔
)
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics,
)
print(f'에포크 : {training_args.num_train_epochs}')
print(f'배치크기 : {training_args.per_device_train_batch_size}')
print(f'학습률 : {training_args.learning_rate}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 from transformers import TrainingArguments, Trainer
#       3 training_args = TrainingArguments(
#       4     output_dir='./results',
#       5     num_train_epochs=2,
#    (...)     11     report_to = 'none'  # W&B TensorBoard 자동 로딩 모두 끔
#      12 )
#      13 trainer = Trainer(
#      14     model=model,
#      15     args=training_args,
#    (...)     18     compute_metrics=compute_metrics,
#      19 )
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2315 elif name in self._class_to_module:
#    2316     try:
# -> 2317         module = self._get_module(self._class_to_module[name])
#    2318         value = getattr(module, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2343 def _get_module(self, module_name: str):
#    2344     try:
# -> 2345         return importlib.import_module("." + module_name, self.__name__)
#    2346     except Exception as e:
#    2347         raise e
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\trainer.py:42
#      37 from typing import TYPE_CHECKING, Any, Callable, Optional, Union
#      40 # Integrations must be imported before ML frameworks:
#      41 # ruff: isort: off
# ---> 42 from .integrations import (
#      43     get_reporting_integration_callbacks,
#      44 )
#      46 # ruff: isort: on
#      48 import huggingface_hub.utils as hf_hub_utils
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2315 elif name in self._class_to_module:
#    2316     try:
# -> 2317         module = self._get_module(self._class_to_module[name])
#    2318         value = getattr(module, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2343 def _get_module(self, module_name: str):
#    2344     try:
# -> 2345         return importlib.import_module("." + module_name, self.__name__)
#    2346     except Exception as e:
#    2347         raise e
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\integrations\integration_utils.py:60
#      57 logger = logging.get_logger(__name__)
#      59 if is_tf_available():
# ---> 60     from .. import TFPreTrainedModel
#      62 if is_torch_available():
#      63     import torch
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2315 elif name in self._class_to_module:
#    2316     try:
# -> 2317         module = self._get_module(self._class_to_module[name])
#    2318         value = getattr(module, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\utils\import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2343 def _get_module(self, module_name: str):
#    2344     try:
# -> 2345         return importlib.import_module("." + module_name, self.__name__)
#    2346     except Exception as e:
#    2347         raise e
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\modeling_tf_utils.py:38
#      35 from packaging.version import parse
#      37 from . import DataCollatorWithPadding, DefaultDataCollator
# ---> 38 from .activations_tf import get_tf_activation
#      39 from .configuration_utils import PretrainedConfig
#      40 from .dynamic_module_utils import custom_object_save
#
# File c:\Users\sally\anaconda3\envs\p311\Lib\site-packages\transformers\activations_tf.py:27
#      24     import keras
#      26     if parse(keras.__version__).major > 2:
# ---> 27         raise ValueError(
#      28             "Your currently installed version of Keras is Keras 3, but this is not yet supported in "
#      29             "Transformers. Please install the backwards-compatible tf-keras package with "
#      30             "`pip install tf-keras`."
#      31         )
#      34 def _gelu(x):
#      35     """
#      36     Gaussian Error Linear Unit. Original Implementation of the gelu activation function in Google Bert repo when
#      37     initially created. For information: OpenAI GPT's gelu is slightly different (and gives slightly different results):
#      38     0.5 * x * (1 + torch.tanh(math.sqrt(2 / math.pi) * (x + 0.044715 * torch.pow(x, 3)))) Also see
#      39     https://huggingface.co/papers/1606.08415
#      40     """
#
# ValueError: Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.

# %%
# 모델 학습
train_result = trainer.train()
print(f'총 학습시간 : {train_result.metrics["train_runtime"]}')
print(f'최종손실 : {train_result.metrics["train_loss"]}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 2
#       1 # 모델 학습
# ----> 2 train_result = trainer.train()
#       3 print(f'총 학습시간 : {train_result.metrics["train_runtime"]}')
#       4 print(f'최종손실 : {train_result.metrics["train_loss"]}')
#
# NameError: name 'trainer' is not defined

# %%
eval_result = trainer.evaluate()
print(f'테스트 정확도 : {eval_result["eval_accuracy"]}')
# 예측수행
predictions = trainer.predict(test_dataset)
pred_labels = np.argmax(predictions.predictions, axis=-1)
# 분류리포트
print(classification_report(test_labels, pred_labels))

# %%
test_reviews = [
    "This movie is absolutely fantastic! The plot is engaging and the acting is superb.",
    "Terrible film. Waste of time and money. Would not recommend to anyone.",
    "It's an okay movie. Nothing special but not terrible either.",
    "Brilliant masterpiece! One of the best films I've ever seen in my life.",
    "Boring and predictable. I fell asleep halfway through."
]

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

# %%
model.eval()
for i,review in enumerate(test_reviews):
  inputs = tokenizer(review,
                     return_tensors="pt",
                     truncation=True,
                     padding=True,
                     max_length=512
                     )
  inputs   = {k:v.to(device) for k,v in inputs.items()}
  with torch.no_grad():
    outputs = model(**inputs)
    logits =  outputs.logits
    probs = torch.softmax(logits, dim=-1)[0]
    pred_class = torch.argmax(probs).item()
  confidence = probs[pred_class].item()
  print(f'문장 : {review}')
  print(f'예측 : {pred_class}')
  print(f'긍정 : {probs[1].item():.4f}')
  print(f'부정 : {probs[0].item():.4f}\n')
